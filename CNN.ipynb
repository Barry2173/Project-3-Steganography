# %%
from itertools import islice
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import torch
from torch.autograd import Variable
from torch import utils
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import os 
import pickle
from torchvision import datasets, utils
import torchvision.transforms as transforms
from torchvision.transforms import ToPILImage
from random import shuffle
from IPython.display import Image

# %%
print(os.path.abspath("."))
# Out:
# /Users/Mashiro/Desktop/Project3

# %%
# Directory path
os.chdir('..')
cwd = '/Users/Mashiro/Desktop/Project3'

# Hyper Parameters
num_epochs = 3
batch_size = 2
learning_rate = 0.0001
beta = 1

# Mean and std deviation of imagenet dataset. Source: http://cs231n.stanford.edu/reports/2017/pdfs/101.pdf
std = [0.229, 0.224, 0.225]
mean = [0.485, 0.456, 0.406]

# TODO: Define train, validation and models
MODELS_PATH = '/Users/Mashiro/Desktop/Project3/output/model/'
# TRAIN_PATH = cwd+'/train/'
# VALID_PATH = cwd+'/valid/'
# VALID_PATH = cwd+'/sample/valid/'
TRAIN_PATH = cwd +'/train/'
TEST_PATH = cwd +'/test/'

if not os.path.exists(MODELS_PATH): os.mkdir(MODELS_PATH)

# %%
def customized_loss(S_prime, C_prime, S, C, B):
    ''' Calculates loss specified on the paper.'''
    
    loss_cover = torch.nn.functional.mse_loss(C_prime, C)
    loss_secret = torch.nn.functional.mse_loss(S_prime, S)
    loss_all = loss_cover + B * loss_secret
    return loss_all, loss_cover, loss_secret

def denormalize(image, std, mean):
    ''' Denormalizes a tensor of images.'''

    for t in range(3):
        image[t, :, :] = (image[t, :, :] * std[t]) + mean[t]
    return image

def imshow(img, idx, learning_rate, beta):
    '''Prints out an image given in tensor format.'''
    
    img = denormalize(img, std, mean)
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.title('Example '+str(idx)+', lr='+str(learning_rate)+', B='+str(beta))
    plt.show()
    return

def gaussian(tensor, mean=0, stddev=0.1):
    '''Adds random noise to a tensor.'''
    
    noise = torch.nn.init.normal(torch.Tensor(tensor.size()), 0, 0.1)
    return Variable(tensor + noise)

# %%
# Preparation Network (2 conv layers)
class PrepNetwork(nn.Module):
    def __init__(self):
        super(PrepNetwork, self).__init__()
        self.initialP3 = nn.Sequential(
            nn.Conv2d(3, 50, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=3, padding=1),
            nn.ReLU())
        self.initialP4 = nn.Sequential(
            nn.Conv2d(3, 50, kernel_size=4, padding=1),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=4, padding=2),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=4, padding=1),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=4, padding=2),
            nn.ReLU())
        self.initialP5 = nn.Sequential(
            nn.Conv2d(3, 50, kernel_size=5, padding=2),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=5, padding=2),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=5, padding=2),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=5, padding=2),
            nn.ReLU())
        self.finalP3 = nn.Sequential(
            nn.Conv2d(150, 50, kernel_size=3, padding=1),
            nn.ReLU())
        self.finalP4 = nn.Sequential(
            nn.Conv2d(150, 50, kernel_size=4, padding=1),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=4, padding=2),
            nn.ReLU())
        self.finalP5 = nn.Sequential(
            nn.Conv2d(150, 50, kernel_size=5, padding=2),
            nn.ReLU())

    def forward(self, p):
        p1 = self.initialP3(p)
        p2 = self.initialP4(p)
        p3 = self.initialP5(p)
        mid = torch.cat((p1, p2, p3), 1)
        p4 = self.finalP3(mid)
        p5 = self.finalP4(mid)
        p6 = self.finalP5(mid)
        out = torch.cat((p4, p5, p6), 1)
        return out
    
# Hiding Network (5 conv layers)
class HidingNetwork(nn.Module):
    def __init__(self):
        super(HidingNetwork, self).__init__()
        self.initialH3 = nn.Sequential(
            nn.Conv2d(153, 50, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=3, padding=1),
            nn.ReLU())
        self.initialH4 = nn.Sequential(
            nn.Conv2d(153, 50, kernel_size=4, padding=1),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=4, padding=2),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=4, padding=1),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=4, padding=2),
            nn.ReLU())
        self.initialH5 = nn.Sequential(
            nn.Conv2d(153, 50, kernel_size=5, padding=2),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=5, padding=2),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=5, padding=2),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=5, padding=2),
            nn.ReLU())
        self.finalH3 = nn.Sequential(
            nn.Conv2d(150, 50, kernel_size=3, padding=1),
            nn.ReLU())
        self.finalH4 = nn.Sequential(
            nn.Conv2d(150, 50, kernel_size=4, padding=1),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=4, padding=2),
            nn.ReLU())
        self.finalH5 = nn.Sequential(
            nn.Conv2d(150, 50, kernel_size=5, padding=2),
            nn.ReLU())
        self.finalH = nn.Sequential(
            nn.Conv2d(150, 3, kernel_size=1, padding=0))
        
    def forward(self, h):
        h1 = self.initialH3(h)
        h2 = self.initialH4(h)
        h3 = self.initialH5(h)
        mid = torch.cat((h1, h2, h3), 1)
        h4 = self.finalH3(mid)
        h5 = self.finalH4(mid)
        h6 = self.finalH5(mid)
        mid2 = torch.cat((h4, h5, h6), 1)
        out = self.finalH(mid2)
        out_noise = gaussian(out.data, 0, 0.1)
        return out, out_noise

# Reveal Network (2 conv layers)
class RevealNetwork(nn.Module):
    def __init__(self):
        super(RevealNetwork, self).__init__()
        self.initialR3 = nn.Sequential(
            nn.Conv2d(3, 50, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=3, padding=1),
            nn.ReLU())
        self.initialR4 = nn.Sequential(
            nn.Conv2d(3, 50, kernel_size=4, padding=1),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=4, padding=2),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=4, padding=1),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=4, padding=2),
            nn.ReLU())
        self.initialR5 = nn.Sequential(
            nn.Conv2d(3, 50, kernel_size=5, padding=2),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=5, padding=2),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=5, padding=2),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=5, padding=2),
            nn.ReLU())
        self.finalR3 = nn.Sequential(
            nn.Conv2d(150, 50, kernel_size=3, padding=1),
            nn.ReLU())
        self.finalR4 = nn.Sequential(
            nn.Conv2d(150, 50, kernel_size=4, padding=1),
            nn.ReLU(),
            nn.Conv2d(50, 50, kernel_size=4, padding=2),
            nn.ReLU())
        self.finalR5 = nn.Sequential(
            nn.Conv2d(150, 50, kernel_size=5, padding=2),
            nn.ReLU())
        self.finalR = nn.Sequential(
            nn.Conv2d(150, 3, kernel_size=1, padding=0))

    def forward(self, r):
        r1 = self.initialR3(r)
        r2 = self.initialR4(r)
        r3 = self.initialR5(r)
        mid = torch.cat((r1, r2, r3), 1)
        r4 = self.finalR3(mid)
        r5 = self.finalR4(mid)
        r6 = self.finalR5(mid)
        mid2 = torch.cat((r4, r5, r6), 1)
        out = self.finalR(mid2)
        return out

# Join three networks in one module
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.m1 = PrepNetwork()
        self.m2 = HidingNetwork()
        self.m3 = RevealNetwork()

    def forward(self, secret, cover):
        x_1 = self.m1(secret)
        mid = torch.cat((x_1, cover), 1)
        x_2, x_2_noise = self.m2(mid)
        x_3 = self.m3(x_2_noise)
        return x_2, x_3

# %%
# Creates net object
net = Net()

# %%
# Creates training set
train_loader = torch.utils.data.DataLoader(
        datasets.ImageFolder(
        TRAIN_PATH,
        transforms.Compose([
        transforms.Scale(256),
        transforms.RandomCrop(224),
        transforms.ToTensor(),
        transforms.Normalize(mean=mean,
        std=std)
        ])), batch_size=batch_size, num_workers=1, 
        pin_memory=True, shuffle=True, drop_last=True)

# Creates test set
test_loader = torch.utils.data.DataLoader(
        datasets.ImageFolder(
        TEST_PATH, 
        transforms.Compose([
        transforms.Scale(256),
        transforms.RandomCrop(224),
        transforms.ToTensor(),
        transforms.Normalize(mean=mean,
        std=std)
        ])), batch_size=2, num_workers=1, 
        pin_memory=True, shuffle=True, drop_last=True)
# Out:
# /anaconda3/lib/python3.7/site-packages/torchvision/transforms/transforms.py:208: UserWarning: The use of the transforms.Scale transform is deprecated, please use transforms.Resize instead.
#   warnings.warn("The use of the transforms.Scale transform is deprecated, " +

# %%
def train_model(train_loader, beta, learning_rate):
    
    # Save optimizer
    optimizer = optim.Adam(net.parameters(), lr=learning_rate)
    
    loss_history = []
    # Iterate over batches performing forward and backward passes
    for epoch in range(num_epochs):

        # Train mode
        net.train()
        
        train_losses = []
        # Train one epoch
        for idx, train_batch in enumerate(train_loader):

            data, _  = train_batch

            # Saves secret images and secret covers
            train_covers = data[:len(data)//2]
            train_secrets = data[len(data)//2:]
            
            # Creates variable from secret and cover images
            train_secrets = Variable(train_secrets, requires_grad=False)
            train_covers = Variable(train_covers, requires_grad=False)

            # Forward + Backward + Optimize
            optimizer.zero_grad()
            train_hidden, train_output = net(train_secrets, train_covers)

            # Calculate loss and perform backprop
            train_loss, train_loss_cover, train_loss_secret = customized_loss(train_output, train_hidden, train_secrets, train_covers, beta)
            train_loss.backward()
            optimizer.step()
            
            # Saves training loss
            train_losses.append(torch.Tensor.item(train_loss.data))
            loss_history.append(torch.Tensor.item(train_loss.data))
            
            # Prints mini-batch losses
            print('Training: Batch {0}/{1}. Loss of {2:.4f}, cover loss of {3:.4f}, secret loss of {4:.4f}'.format(idx+1, len(train_loader), (torch.Tensor.item(train_loss.data)), torch.Tensor.item(train_loss_cover.data), torch.Tensor.item(train_loss_secret.data)))
            
        torch.save(net.state_dict(), MODELS_PATH+'Epoch N{}.pkl'.format(epoch+1))
        
        mean_train_loss = np.mean(train_losses)
    
        # Prints epoch average loss
        print ('Epoch [{0}/{1}], Average_loss: {2:.4f}'.format(
                epoch+1, num_epochs, mean_train_loss))
    
    return net, mean_train_loss, loss_history

# %%
net, mean_train_loss, loss_history = train_model(train_loader, beta, learning_rate)
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: nn.init.normal is now deprecated in favor of nn.init.normal_.
# Training: Batch 1/60. Loss of 1.8091, cover loss of 0.7659, secret loss of 1.0432
# Training: Batch 2/60. Loss of 1.2054, cover loss of 0.4715, secret loss of 0.7339
# Training: Batch 3/60. Loss of 3.1527, cover loss of 1.8357, secret loss of 1.3170
# Training: Batch 4/60. Loss of 1.1590, cover loss of 0.4317, secret loss of 0.7273
# Training: Batch 5/60. Loss of 0.8688, cover loss of 0.5667, secret loss of 0.3021
# Training: Batch 6/60. Loss of 2.0711, cover loss of 1.1376, secret loss of 0.9335
# Training: Batch 7/60. Loss of 2.3871, cover loss of 1.0977, secret loss of 1.2894
# Training: Batch 8/60. Loss of 3.5380, cover loss of 0.7085, secret loss of 2.8295
# Training: Batch 9/60. Loss of 3.5789, cover loss of 1.3573, secret loss of 2.2216
# Training: Batch 10/60. Loss of 3.3674, cover loss of 1.7204, secret loss of 1.6470
# Training: Batch 11/60. Loss of 1.3120, cover loss of 1.1127, secret loss of 0.1993
# Training: Batch 12/60. Loss of 1.8634, cover loss of 0.5416, secret loss of 1.3218
# Training: Batch 13/60. Loss of 1.3794, cover loss of 0.4958, secret loss of 0.8836
# Training: Batch 14/60. Loss of 2.0654, cover loss of 1.7484, secret loss of 0.3170
# Training: Batch 15/60. Loss of 1.8886, cover loss of 0.9561, secret loss of 0.9325
# Training: Batch 16/60. Loss of 1.8780, cover loss of 1.6691, secret loss of 0.2089
# Training: Batch 17/60. Loss of 0.7281, cover loss of 0.5151, secret loss of 0.2130
# Training: Batch 18/60. Loss of 1.4908, cover loss of 0.8950, secret loss of 0.5958
# Training: Batch 19/60. Loss of 4.7156, cover loss of 3.6074, secret loss of 1.1082
# Training: Batch 20/60. Loss of 1.1894, cover loss of 0.5468, secret loss of 0.6426
# Training: Batch 21/60. Loss of 2.8226, cover loss of 1.7563, secret loss of 1.0663
# Training: Batch 22/60. Loss of 1.3751, cover loss of 0.8590, secret loss of 0.5160
# Training: Batch 23/60. Loss of 1.4422, cover loss of 0.5822, secret loss of 0.8599
# Training: Batch 24/60. Loss of 2.3544, cover loss of 0.5362, secret loss of 1.8183
# Training: Batch 25/60. Loss of 1.3118, cover loss of 0.3788, secret loss of 0.9329
# Training: Batch 26/60. Loss of 1.0194, cover loss of 0.6659, secret loss of 0.3535
# Training: Batch 27/60. Loss of 1.7511, cover loss of 0.5340, secret loss of 1.2171
# Training: Batch 28/60. Loss of 1.3945, cover loss of 0.5384, secret loss of 0.8561
# Training: Batch 29/60. Loss of 2.7660, cover loss of 1.1081, secret loss of 1.6579
# Training: Batch 30/60. Loss of 1.7477, cover loss of 1.1471, secret loss of 0.6006
# Training: Batch 31/60. Loss of 1.6760, cover loss of 0.4784, secret loss of 1.1976
# Training: Batch 32/60. Loss of 1.2180, cover loss of 0.5012, secret loss of 0.7168
# Training: Batch 33/60. Loss of 1.9246, cover loss of 1.0111, secret loss of 0.9135
# Training: Batch 34/60. Loss of 1.6276, cover loss of 0.3719, secret loss of 1.2557
# Training: Batch 35/60. Loss of 0.9783, cover loss of 0.4552, secret loss of 0.5231
# Training: Batch 36/60. Loss of 1.2597, cover loss of 0.4577, secret loss of 0.8020
# Training: Batch 37/60. Loss of 1.5749, cover loss of 0.3577, secret loss of 1.2172
# Training: Batch 38/60. Loss of 1.4000, cover loss of 0.7825, secret loss of 0.6175
# Training: Batch 39/60. Loss of 0.8794, cover loss of 0.4078, secret loss of 0.4716
# Training: Batch 40/60. Loss of 2.7967, cover loss of 1.2084, secret loss of 1.5883
# Training: Batch 41/60. Loss of 1.9895, cover loss of 1.5565, secret loss of 0.4330
# Training: Batch 42/60. Loss of 0.6954, cover loss of 0.2795, secret loss of 0.4159
# Training: Batch 43/60. Loss of 2.5357, cover loss of 1.6488, secret loss of 0.8868
# Training: Batch 44/60. Loss of 1.0135, cover loss of 0.7403, secret loss of 0.2733
# Training: Batch 45/60. Loss of 1.0268, cover loss of 0.6417, secret loss of 0.3852
# Training: Batch 46/60. Loss of 0.8195, cover loss of 0.3608, secret loss of 0.4587
# Training: Batch 47/60. Loss of 1.5235, cover loss of 0.7913, secret loss of 0.7322
# Training: Batch 48/60. Loss of 1.7577, cover loss of 0.9066, secret loss of 0.8511
# Training: Batch 49/60. Loss of 1.8055, cover loss of 1.0282, secret loss of 0.7773
# Training: Batch 50/60. Loss of 0.9878, cover loss of 0.5371, secret loss of 0.4507
# Training: Batch 51/60. Loss of 0.7967, cover loss of 0.4401, secret loss of 0.3566
# Training: Batch 52/60. Loss of 1.9866, cover loss of 0.9067, secret loss of 1.0800
# Training: Batch 53/60. Loss of 1.1162, cover loss of 0.3623, secret loss of 0.7539
# Training: Batch 54/60. Loss of 1.9497, cover loss of 0.3039, secret loss of 1.6458
# Training: Batch 55/60. Loss of 1.7095, cover loss of 0.6562, secret loss of 1.0533
# Training: Batch 56/60. Loss of 1.4054, cover loss of 0.4016, secret loss of 1.0038
# Training: Batch 57/60. Loss of 0.6584, cover loss of 0.1581, secret loss of 0.5003
# Training: Batch 58/60. Loss of 1.2909, cover loss of 0.5032, secret loss of 0.7877
# Training: Batch 59/60. Loss of 1.7391, cover loss of 0.4302, secret loss of 1.3089
# Training: Batch 60/60. Loss of 0.4719, cover loss of 0.1638, secret loss of 0.3080
# Epoch [1/3], Average_loss: 1.7041
# Training: Batch 1/60. Loss of 1.4956, cover loss of 0.2845, secret loss of 1.2111
# Training: Batch 2/60. Loss of 1.5488, cover loss of 0.4328, secret loss of 1.1160
# Training: Batch 3/60. Loss of 3.1187, cover loss of 0.8943, secret loss of 2.2244
# Training: Batch 4/60. Loss of 0.7145, cover loss of 0.5532, secret loss of 0.1613
# Training: Batch 5/60. Loss of 0.4203, cover loss of 0.2190, secret loss of 0.2012
# Training: Batch 6/60. Loss of 1.4801, cover loss of 0.3060, secret loss of 1.1742
# Training: Batch 7/60. Loss of 1.1955, cover loss of 0.3356, secret loss of 0.8599
# Training: Batch 8/60. Loss of 1.2806, cover loss of 0.3311, secret loss of 0.9495
# Training: Batch 9/60. Loss of 1.4284, cover loss of 0.1905, secret loss of 1.2378
# Training: Batch 10/60. Loss of 1.0460, cover loss of 0.3036, secret loss of 0.7424
# Training: Batch 11/60. Loss of 2.2615, cover loss of 0.3546, secret loss of 1.9068
# Training: Batch 12/60. Loss of 2.0740, cover loss of 0.5169, secret loss of 1.5571
# Training: Batch 13/60. Loss of 0.6005, cover loss of 0.1620, secret loss of 0.4385
# Training: Batch 14/60. Loss of 1.4393, cover loss of 0.3416, secret loss of 1.0977
# Training: Batch 15/60. Loss of 1.5407, cover loss of 0.5772, secret loss of 0.9635
# Training: Batch 16/60. Loss of 1.0591, cover loss of 0.2634, secret loss of 0.7958
# Training: Batch 17/60. Loss of 2.3027, cover loss of 0.2226, secret loss of 2.0800
# Training: Batch 18/60. Loss of 0.7230, cover loss of 0.3525, secret loss of 0.3705
# Training: Batch 19/60. Loss of 0.9452, cover loss of 0.2322, secret loss of 0.7130
# Training: Batch 20/60. Loss of 1.1937, cover loss of 0.3131, secret loss of 0.8806
# Training: Batch 21/60. Loss of 0.8361, cover loss of 0.1365, secret loss of 0.6996
# Training: Batch 22/60. Loss of 1.3846, cover loss of 0.3459, secret loss of 1.0387
# Training: Batch 23/60. Loss of 1.0743, cover loss of 0.4988, secret loss of 0.5755
# Training: Batch 24/60. Loss of 1.1688, cover loss of 0.3815, secret loss of 0.7873
# Training: Batch 25/60. Loss of 1.4043, cover loss of 0.1907, secret loss of 1.2136
# Training: Batch 26/60. Loss of 1.1278, cover loss of 0.2623, secret loss of 0.8655
# Training: Batch 27/60. Loss of 2.3925, cover loss of 0.2442, secret loss of 2.1483
# Training: Batch 28/60. Loss of 1.4955, cover loss of 0.3121, secret loss of 1.1834
# Training: Batch 29/60. Loss of 2.2801, cover loss of 0.2946, secret loss of 1.9855
# Training: Batch 30/60. Loss of 0.7626, cover loss of 0.2825, secret loss of 0.4801
# Training: Batch 31/60. Loss of 1.0923, cover loss of 0.3310, secret loss of 0.7613
# Training: Batch 32/60. Loss of 1.5765, cover loss of 0.2491, secret loss of 1.3274
# Training: Batch 33/60. Loss of 0.5627, cover loss of 0.1237, secret loss of 0.4390
# Training: Batch 34/60. Loss of 0.7619, cover loss of 0.3655, secret loss of 0.3963
# Training: Batch 35/60. Loss of 0.6370, cover loss of 0.1905, secret loss of 0.4465
# Training: Batch 36/60. Loss of 1.8129, cover loss of 0.2437, secret loss of 1.5693
# Training: Batch 37/60. Loss of 1.8955, cover loss of 0.0792, secret loss of 1.8164
# Training: Batch 38/60. Loss of 0.8309, cover loss of 0.0921, secret loss of 0.7388
# Training: Batch 39/60. Loss of 1.8004, cover loss of 0.1660, secret loss of 1.6344
# Training: Batch 40/60. Loss of 0.4447, cover loss of 0.2011, secret loss of 0.2436
# Training: Batch 41/60. Loss of 2.1157, cover loss of 0.1918, secret loss of 1.9238
# Training: Batch 42/60. Loss of 0.9780, cover loss of 0.2000, secret loss of 0.7780
# Training: Batch 43/60. Loss of 1.8797, cover loss of 0.1970, secret loss of 1.6827
# Training: Batch 44/60. Loss of 1.9277, cover loss of 0.3391, secret loss of 1.5886
# Training: Batch 45/60. Loss of 1.3615, cover loss of 0.4625, secret loss of 0.8990
# Training: Batch 46/60. Loss of 0.7318, cover loss of 0.0848, secret loss of 0.6470
# Training: Batch 47/60. Loss of 0.9283, cover loss of 0.2464, secret loss of 0.6818
# Training: Batch 48/60. Loss of 1.1539, cover loss of 0.2488, secret loss of 0.9051
# Training: Batch 49/60. Loss of 0.6113, cover loss of 0.2963, secret loss of 0.3150
# Training: Batch 50/60. Loss of 0.5513, cover loss of 0.0993, secret loss of 0.4521
# Training: Batch 51/60. Loss of 0.5551, cover loss of 0.2077, secret loss of 0.3474
# Training: Batch 52/60. Loss of 0.8776, cover loss of 0.0956, secret loss of 0.7820
# Training: Batch 53/60. Loss of 1.2441, cover loss of 0.3494, secret loss of 0.8947
# Training: Batch 54/60. Loss of 1.1455, cover loss of 0.2112, secret loss of 0.9343
# Training: Batch 55/60. Loss of 1.9881, cover loss of 0.1747, secret loss of 1.8133
# Training: Batch 56/60. Loss of 1.1424, cover loss of 0.5919, secret loss of 0.5506
# Training: Batch 57/60. Loss of 0.7036, cover loss of 0.1203, secret loss of 0.5833
# Training: Batch 58/60. Loss of 1.6849, cover loss of 0.3389, secret loss of 1.3460
# Training: Batch 59/60. Loss of 1.5997, cover loss of 0.2074, secret loss of 1.3924
# Training: Batch 60/60. Loss of 0.8214, cover loss of 0.3447, secret loss of 0.4767
# Epoch [2/3], Average_loss: 1.2869
# Training: Batch 1/60. Loss of 1.1959, cover loss of 0.5779, secret loss of 0.6180
# Training: Batch 2/60. Loss of 1.3696, cover loss of 0.4009, secret loss of 0.9687
# Training: Batch 3/60. Loss of 0.7807, cover loss of 0.2416, secret loss of 0.5391
# Training: Batch 4/60. Loss of 1.5171, cover loss of 0.5282, secret loss of 0.9889
# Training: Batch 5/60. Loss of 0.7828, cover loss of 0.2806, secret loss of 0.5022
# Training: Batch 6/60. Loss of 1.7510, cover loss of 0.5191, secret loss of 1.2319
# Training: Batch 7/60. Loss of 2.4862, cover loss of 0.8941, secret loss of 1.5921
# Training: Batch 8/60. Loss of 0.6231, cover loss of 0.1732, secret loss of 0.4499
# Training: Batch 9/60. Loss of 0.6378, cover loss of 0.1218, secret loss of 0.5160
# Training: Batch 10/60. Loss of 0.3342, cover loss of 0.1401, secret loss of 0.1941
# Training: Batch 11/60. Loss of 2.0339, cover loss of 0.3313, secret loss of 1.7026
# Training: Batch 12/60. Loss of 0.6731, cover loss of 0.3137, secret loss of 0.3594
# Training: Batch 13/60. Loss of 1.0874, cover loss of 0.2541, secret loss of 0.8333
# Training: Batch 14/60. Loss of 0.9048, cover loss of 0.2099, secret loss of 0.6949
# Training: Batch 15/60. Loss of 0.7141, cover loss of 0.2167, secret loss of 0.4974
# Training: Batch 16/60. Loss of 1.4752, cover loss of 0.3843, secret loss of 1.0909
# Training: Batch 17/60. Loss of 1.4603, cover loss of 0.2426, secret loss of 1.2177
# Training: Batch 18/60. Loss of 1.9391, cover loss of 0.2095, secret loss of 1.7296
# Training: Batch 19/60. Loss of 1.1513, cover loss of 0.1620, secret loss of 0.9893
# Training: Batch 20/60. Loss of 0.9403, cover loss of 0.1889, secret loss of 0.7515
# Training: Batch 21/60. Loss of 0.8157, cover loss of 0.4450, secret loss of 0.3706
# Training: Batch 22/60. Loss of 1.1218, cover loss of 0.7999, secret loss of 0.3219
# Training: Batch 23/60. Loss of 0.6213, cover loss of 0.3977, secret loss of 0.2236
# Training: Batch 24/60. Loss of 1.0858, cover loss of 0.1029, secret loss of 0.9830
# Training: Batch 25/60. Loss of 0.8195, cover loss of 0.2327, secret loss of 0.5868
# Training: Batch 26/60. Loss of 0.6492, cover loss of 0.0310, secret loss of 0.6182
# Training: Batch 27/60. Loss of 1.2239, cover loss of 0.0842, secret loss of 1.1397
# Training: Batch 28/60. Loss of 1.2312, cover loss of 0.3186, secret loss of 0.9127
# Training: Batch 29/60. Loss of 1.1242, cover loss of 0.1940, secret loss of 0.9301
# Training: Batch 30/60. Loss of 0.6345, cover loss of 0.0703, secret loss of 0.5642
# Training: Batch 31/60. Loss of 1.9455, cover loss of 0.1872, secret loss of 1.7583
# Training: Batch 32/60. Loss of 1.4204, cover loss of 0.1294, secret loss of 1.2910
# Training: Batch 33/60. Loss of 0.5481, cover loss of 0.2379, secret loss of 0.3102
# Training: Batch 34/60. Loss of 2.6042, cover loss of 0.1680, secret loss of 2.4362
# Training: Batch 35/60. Loss of 1.2997, cover loss of 0.1798, secret loss of 1.1199
# Training: Batch 36/60. Loss of 0.8679, cover loss of 0.3028, secret loss of 0.5651
# Training: Batch 37/60. Loss of 0.9923, cover loss of 0.2064, secret loss of 0.7860
# Training: Batch 38/60. Loss of 1.7137, cover loss of 0.1629, secret loss of 1.5508
# Training: Batch 39/60. Loss of 1.5818, cover loss of 0.3123, secret loss of 1.2695
# Training: Batch 40/60. Loss of 1.7667, cover loss of 0.2749, secret loss of 1.4918
# Training: Batch 41/60. Loss of 1.2222, cover loss of 0.1741, secret loss of 1.0481
# Training: Batch 42/60. Loss of 1.1255, cover loss of 0.1126, secret loss of 1.0129
# Training: Batch 43/60. Loss of 0.5055, cover loss of 0.1793, secret loss of 0.3262
# Training: Batch 44/60. Loss of 0.9740, cover loss of 0.2396, secret loss of 0.7344
# Training: Batch 45/60. Loss of 2.0645, cover loss of 0.2312, secret loss of 1.8333
# Training: Batch 46/60. Loss of 1.3022, cover loss of 0.2383, secret loss of 1.0639
# Training: Batch 47/60. Loss of 2.3342, cover loss of 0.2809, secret loss of 2.0534
# Training: Batch 48/60. Loss of 0.7319, cover loss of 0.1831, secret loss of 0.5488
# Training: Batch 49/60. Loss of 0.6131, cover loss of 0.1566, secret loss of 0.4565
# Training: Batch 50/60. Loss of 1.2170, cover loss of 0.7218, secret loss of 0.4952
# Training: Batch 51/60. Loss of 1.9137, cover loss of 0.1850, secret loss of 1.7287
# Training: Batch 52/60. Loss of 0.6491, cover loss of 0.1071, secret loss of 0.5420
# Training: Batch 53/60. Loss of 1.2830, cover loss of 0.2846, secret loss of 0.9984
# Training: Batch 54/60. Loss of 1.0100, cover loss of 0.2835, secret loss of 0.7265
# Training: Batch 55/60. Loss of 0.9445, cover loss of 0.0394, secret loss of 0.9051
# Training: Batch 56/60. Loss of 0.5379, cover loss of 0.1842, secret loss of 0.3536
# Training: Batch 57/60. Loss of 1.2402, cover loss of 0.1348, secret loss of 1.1054
# Training: Batch 58/60. Loss of 0.7700, cover loss of 0.2832, secret loss of 0.4869
# Training: Batch 59/60. Loss of 1.5778, cover loss of 0.3785, secret loss of 1.1992
# Training: Batch 60/60. Loss of 1.4311, cover loss of 0.5912, secret loss of 0.8399
# Epoch [3/3], Average_loss: 1.1895

# %%
# net.load_state_dict(torch.load(MODELS_PATH+'Epoch N4.pkl'))

# Switch to evaluate mode
net.eval()

test_losses = []
# Show images
for idx, test_batch in enumerate(test_loader):
     # Saves images
    data, _ = test_batch

    # Saves secret images and secret covers
    test_secret = data[:len(data)//2]
    test_cover = data[len(data)//2:]

    # Creates variable from secret and cover images
    test_secret = Variable(test_secret, volatile=True)
    test_cover = Variable(test_cover, volatile=True)

    # Compute output
    test_hidden, test_output = net(test_secret, test_cover)
    
    # Calculate loss
    test_loss, loss_cover, loss_secret = customized_loss(test_output, test_hidden, test_secret, test_cover, beta)
    
#     diff_S, diff_C = np.abs(np.array(test_output.data[0]) - np.array(test_secret.data[0])), np.abs(np.array(test_hidden.data[0]) - np.array(test_cover.data[0]))
    
#     print (diff_S, diff_C)

    if idx < 100:
        print ('Total loss: {:.2f} \nLoss on secret: {:.2f} \nLoss on cover: {:.2f}'.format(torch.Tensor.item(test_loss.data), torch.Tensor.item(loss_secret.data), torch.Tensor.item(loss_cover.data)))
        # Creates img tensor
        imgs = [test_secret.data, test_output.data, test_cover.data, test_hidden.data]
        imgs_tsor = torch.cat(imgs, 0)

        # Prints Images
        imshow(utils.make_grid(imgs_tsor), idx+1, learning_rate=learning_rate, beta=beta)
        
    test_losses.append(torch.Tensor.item(test_loss.data))
        
mean_test_loss = np.mean(test_losses)

print ('Average loss on test set: {:.2f}'.format(mean_test_loss))
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:17: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:18: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:29: UserWarning: nn.init.normal is now deprecated in favor of nn.init.normal_.
# Total loss: 0.79
# Loss on secret: 0.46
# Loss on cover: 0.33
# Total loss: 2.05
# Loss on secret: 1.99
# Loss on cover: 0.06
# Total loss: 0.63
# Loss on secret: 0.54
# Loss on cover: 0.09
# Total loss: 1.49
# Loss on secret: 1.22
# Loss on cover: 0.26
# Total loss: 0.59
# Loss on secret: 0.43
# Loss on cover: 0.17
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Total loss: 0.93
# Loss on secret: 0.81
# Loss on cover: 0.11
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Total loss: 3.61
# Loss on secret: 3.50
# Loss on cover: 0.11
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Total loss: 0.69
# Loss on secret: 0.64
# Loss on cover: 0.05
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Total loss: 0.97
# Loss on secret: 0.84
# Loss on cover: 0.13
# Total loss: 0.80
# Loss on secret: 0.69
# Loss on cover: 0.11
# Total loss: 0.89
# Loss on secret: 0.66
# Loss on cover: 0.23
# Total loss: 0.58
# Loss on secret: 0.46
# Loss on cover: 0.12
# Average loss on test set: 1.17
